# %%
import pandas as pd 
import numpy as np 
import os
# Out:
# C:\Users\Arda\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# Get predictions for next matches

# %% [markdown]
# Predicts

# %%
urdir=os.getcwd()[:-9]+"data\\"

# %%
predicts=pd.read_excel(f"{urdir}predicts.xlsx")
predicts.head()
# Out:
#    fixture.id  league.id league.name league.country         league.round  \
# 0     1202777        210         HNL        Croatia  Regular Season - 27
# 1     1202778        210         HNL        Croatia  Regular Season - 27
# 2     1202779        210         HNL        Croatia  Regular Season - 27
# 3     1202780        210         HNL        Croatia  Regular Season - 27
# 4     1202781        210         HNL        Croatia  Regular Season - 27
#
#         teams.home.name teams.away.name     preds   Lower_q   Upper_q  \
# 0      HNK Hajduk Split         Sibenik  2.224827 -0.391764  3.434978
# 1      NK Slaven Belupo      HNK Rijeka  1.958386 -2.141230  4.696444
# 2  NK Lokomotiva Zagreb      HNK Gorica  2.230792  0.059399  3.279305
# 3           NK Varazdin   Dinamo Zagreb  2.135499  1.010532  4.423082
# 4            Istra 1961       NK Osijek  2.071054 -0.859660  4.050808
#
#      odd_up  odd_down
# 0  0.244327  0.755673
# 1  0.321227  0.678773
# 2  0.242027  0.757973
# ...

# %%
#Saved Fixtures 

savefix= pd.read_csv(f"{urdir}saved_fixtures.csv")

savefix
# Out:
# C:\Users\Arda\AppData\Local\Temp\ipykernel_11420\54413567.py:3: DtypeWarning: Columns (36) have mixed types. Specify dtype option on import or set low_memory=False.
#   savefix= pd.read_csv(f"{urdir}saved_fixtures.csv")
#         fixture.id                  fixture.referee fixture.timezone  \
# 0           185545            Fredy Fautrel, France              UTC
# 1           185546            Wilfried Bien, France              UTC
# 2           185547  Hakim Ben el Salem Hadj, France              UTC
# 3           185548          Lionel Jaffredo, France              UTC
# 4           185549          Frank Schneider, France              UTC
# ...            ...                              ...              ...
# 104179     1354223              Edina Alves Batista              UTC
# 104180     1357839        Matheus Delgado Candançan              UTC
# 104181     1358545        Flavio Rodrigues De Souza              UTC
# ...

# %%
fixs=predicts["fixture.id"].values.tolist()

# %%
relevantfix=savefix[["fixture.id", 
         "fixture.date", "fixture.timezone",
         "fixture.referee",
         "fixture.venue.name",
           "fixture.venue.city",
           "league.country",
           "league.name",
           "league.logo",
           "league.season",
           "league.round"
               ]][savefix["fixture.id"].isin(fixs)]
relevantfix.head()
# Out:
#        fixture.id               fixture.date fixture.timezone fixture.referee  \
# 93348     1208317  2025-04-01T18:45:00+00:00              UTC             NaN
# 93349     1208314  2025-04-01T18:45:00+00:00              UTC             NaN
# 93350     1208316  2025-04-01T19:00:00+00:00              UTC             NaN
# 93351     1208320  2025-04-02T18:45:00+00:00              UTC             NaN
# 93352     1208313  2025-04-02T18:45:00+00:00              UTC             NaN
#
#       fixture.venue.name            fixture.venue.city league.country  \
# 93348   Molineux Stadium  Wolverhampton, West Midlands        England
# 93349   Emirates Stadium                        London        England
# 93350    The City Ground   Nottingham, Nottinghamshire        England
# 93351    St. James' Park           Newcastle upon Tyne        England
# 93352   Vitality Stadium           Bournemouth, Dorset        England
#
#           league.name                                        league.logo  \
# ...

# %%
relevantfix["short_date"]=relevantfix["fixture.date"].str[:10]
relevantfix["fixture_time"]=relevantfix["fixture.date"].str[11:16]
relevantfix
# Out:
#         fixture.id               fixture.date fixture.timezone  \
# 93348      1208317  2025-04-01T18:45:00+00:00              UTC
# 93349      1208314  2025-04-01T18:45:00+00:00              UTC
# 93350      1208316  2025-04-01T19:00:00+00:00              UTC
# 93351      1208320  2025-04-02T18:45:00+00:00              UTC
# 93352      1208313  2025-04-02T18:45:00+00:00              UTC
# ...            ...                        ...              ...
# 103848     1252652  2025-04-06T16:00:00+00:00              UTC
# 103849     1252646  2025-04-06T18:00:00+00:00              UTC
# 104078     1361563  2025-03-29T14:00:00+00:00              UTC
# 104079     1361564  2025-03-30T14:00:00+00:00              UTC
# 104183     1360314  2025-03-28T00:35:00+00:00              UTC
#
#        fixture.referee                  fixture.venue.name  \
# 93348              NaN                    Molineux Stadium
# 93349              NaN                    Emirates Stadium
# ...

# %%
relevantfix
# Out:
#         fixture.id               fixture.date fixture.timezone  \
# 93348      1208317  2025-04-01T18:45:00+00:00              UTC
# 93349      1208314  2025-04-01T18:45:00+00:00              UTC
# 93350      1208316  2025-04-01T19:00:00+00:00              UTC
# 93351      1208320  2025-04-02T18:45:00+00:00              UTC
# 93352      1208313  2025-04-02T18:45:00+00:00              UTC
# ...            ...                        ...              ...
# 103848     1252652  2025-04-06T16:00:00+00:00              UTC
# 103849     1252646  2025-04-06T18:00:00+00:00              UTC
# 104078     1361563  2025-03-29T14:00:00+00:00              UTC
# 104079     1361564  2025-03-30T14:00:00+00:00              UTC
# 104183     1360314  2025-03-28T00:35:00+00:00              UTC
#
#        fixture.referee                  fixture.venue.name  \
# 93348              NaN                    Molineux Stadium
# 93349              NaN                    Emirates Stadium
# ...
